# %%
class student:
    def __init__(self,name,surname,yob,country):
        self.name =name # Public variable
        self._surname=surname # Private variable
        self.__yob = yob # Protected variable
        self.country=country
stu1 = student('Raj','Dubey',1997,'India')
stu2 = student('John','walker',1994,'France')

print(stu1.name)
print(stu2._surname)
print(stu2._student__yob)

class ineuron:
    mail_id = input('Provide your mail id for sign up ')
    __password = input('Provide password for sign up ')
    def sign_up_details(self):
        print('Mail id for log in is :',ineuron.mail_id,'and password is :',ineuron.__password) # Use of abstraction

i=ineuron()
print(i.sign_up_details())
print(i._ineuron__password)

class course(ineuron):
    course_to_inrolled = input('Provide the course name you have enrolled ')
    def enrolled_course(self):
        print('User of mail id ',ineuron.mail_id,'has enrolled course of ',course.course_to_inrolled)
i1 = course()
print(i1.enrolled_course())

class course_change(course):
    __new_course = input('If you want to update to new course , provide course name : ')
    print('Your previous enrolled course was : ',course.course_to_inrolled)
    def enrolled_course(self):
        print('user of mail id : ',ineuron.mail_id,'has update previous course to :',course_change.__new_course) # use of incapsulation

i5 = course_change()
print(i5.enrolled_course())

def final_course ():
    XY = input('Have you updated your initial course , reply in yes or no :')
    if XY == 'yes':
        i5.enrolled_course()
    if XY == 'no':
        i1.enrolled_course()

final_course()# Use of polymorphizm

class task:
    def task(self):
        print('Every one who have enrolled the course need to complete atleast 60% assignment')
        print('Every one need to complete the tasks given in class to meet the pace and do as much possible practice of code ')
i2 = task()
print(i2.task())

class course_evaluation:
    n= int(input('Provide the number of assignment submitted '))
    n1 = int(input('Provide no of quizz attended : '))
    mark = 50* n
    mark1 = 50 * n1
    def marks(self):
        print('Your total assignment marks is ',course_evaluation.mark )
    def quizz(self):
        print('Your marks of Quizz is  :',course_evaluation.mark1)
i3= course_evaluation()
print(i3.marks())
print(i3.quizz())

class internship:
    Marks = course_evaluation.mark + course_evaluation.mark1
    if Marks > 6000 :
        print('You are eligible for internship and submit the form with your detailsv')
    else:
        print('You need to score total of more than 6000 to be part of internship ')

class Total_mark(internship):
    n = int(input('Provide the numbers of internship you have done '))
    Internsip_score = n * 500
    Total = Internsip_score + internship.Marks
    print('Your overall total marks is : ', Total)
    if internship.Marks >= 7000 and Internsip_score >= 1000:
        if Total > 8000 :
            print('Your have excellent score and do regular practice to keep it up ')
    else:
        print('Improve on all aspect to increase your Total marks ')

class certificate(Total_mark):# Use of multi layer Inheritenance
    X = Total_mark.Total
    if X >7000 :
        print('Your certificate will be mailed on your registered mail_id ')
    else:
        print('Complete assignment and attend quizz as per guidelines ')

class job(certificate):
    try:
        N = int(input('Provide your total work experience '))
        if certificate.X > 8000 and Total_mark.Internsip_score >= 1000 and N >=2:
            print('You are eligible to apply for lateral entry ')
        if certificate.X > 8000 and Total_mark.Internsip_score >= 1000 and N >= 1 and N < 2 :
            print('You are eligible to apply for role of Data analysist ')
        if certificate.X < 8000 and Total_mark.Internsip_score < 1000 and N <1:
            print('You are eligible to apply as fresher ')
        else:
            print('You are not eligible to apply for job , work hard , Best of luch for next time and come strong ')
    except Exception as e:
        print('Provide natural number only ')

class offer_letter:
    print('Students who have cleared the interview has been informed throught mail ')
    Join_day_chng = input('Do you want to change joining day as per your flexibility or go with our option :')
    if Join_day_chng == 'yes':
        print('Drop us a mail with desired change')
    else:
        print('We welcome you in our organisation and look forward to work as team ')

class company_performane (course):
    job_course = input('Provide the name of course from which you have secured job out of all being enroled ')
    def enrolled_course(self):
        print('User of mail id : ',course.mail_id,'has secured job from course : ',company_performane.job_course)

i4 = company_performane()
print(i4.enrolled_course())
# Out:
# Raj
# walker
# 1994
# Provide your mail id for sign up amrit224raj@gmail.com
# Provide password for sign up Amrit@12345
# Mail id for log in is : amrit224raj@gmail.com and password is : Amrit@12345
# None
# Amrit@12345
# Provide the course name you have enrolled Data Science
# User of mail id  amrit224raj@gmail.com has enrolled course of  Data Science
# None
# If you want to update to new course , provide course name : No
# Your previous enrolled course was :  Data Science
# user of mail id :  amrit224raj@gmail.com has update previous course to : No
# None
# Have you updated your initial course , reply in yes or no :no
# User of mail id  amrit224raj@gmail.com has enrolled course of  Data Science
# Every one who have enrolled the course need to complete atleast 60% assignment
# Every one need to complete the tasks given in class to meet the pace and do as much possible practice of code
# None
# Provide the number of assignment submitted 86
# Provide no of quizz attended : 0
# ...
